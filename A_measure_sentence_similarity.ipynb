# %% [markdown]
# # Simple Sentence Similarity (from github) - with application of the methods to a sample dataset at the end

# %% [markdown]
# Word embeddings have become widespread in Natural Language Processing. They allow us to easily compute the semantic similarity between two words, or to find the words most similar to a target word. However, in many applications we're more interested in the similarity between two sentences or short texts. In this notebook, I compare some simple ways of computing sentence similarity and investigate how they perform.

# %%
import pandas as pd
import numpy as np
import scipy
import os
import matplotlib.pyplot as plt

# %% [markdown]
# ## Preparation
#
# First we need to do some preparation: some of our models require the sentences to be tokenized, some do not. For that reason we'll make a simple Sentence class where we keep both the raw sentence and the tokenized sentence. The individual methods below will then pick the input they need.

# %%
import nltk

STOP = set(nltk.corpus.stopwords.words("english"))

class Sentence:
    
    def __init__(self, sentence):
        self.raw = sentence
        normalized_sentence = sentence.replace("‘", "'").replace("’", "'")
        self.tokens = [t.lower() for t in nltk.word_tokenize(normalized_sentence)]
        self.tokens_without_stop = [t for t in self.tokens if t not in STOP]

# %% [markdown]
# Next, we're going to use the popular [Gensim](https://radimrehurek.com/gensim/) library to load aset of widely used pre-trained word embeddings:
# [word2vec](https://www.tensorflow.org/tutorials/word2vec)

# %%
import gensim

from gensim.models import Word2Vec
from gensim.scripts.glove2word2vec import glove2word2vec

PATH_TO_WORD2VEC = os.path.expanduser("models/GoogleNews-vectors-negative300.bin")
word2vec = gensim.models.KeyedVectors.load_word2vec_format(PATH_TO_WORD2VEC, binary=True, limit=500000)

# %% [markdown]
# Finally, in order to compute weighted averages of word embeddings later, we are going to load a file with word frequencies. These word frequencies have been collected from Wikipedia and saved in a tab-separated file.

# %%
import csv

PATH_TO_FREQUENCIES_FILE = "frequencies/sentence_similarity/frequencies.tsv"
PATH_TO_DOC_FREQUENCIES_FILE = "frequencies/sentence_similarity/doc_frequencies.tsv"

def read_tsv(f):
    frequencies = {}
    with open(f) as tsv:
        tsv_reader = csv.reader(tsv, delimiter="\t")
        for row in tsv_reader: 
            frequencies[row[0]] = int(row[1])
        
    return frequencies
        
frequencies = read_tsv(PATH_TO_FREQUENCIES_FILE)
doc_frequencies = read_tsv(PATH_TO_DOC_FREQUENCIES_FILE)
doc_frequencies["NUM_DOCS"] = 1288431

# %% [markdown]
# ## Similarity methods

# %% [markdown]
# ### Baseline
#
# As our baseline, we're going for the simplest way of computing sentence embeddings: just take the embeddings of the words in the sentence (minus the stopwords), and compute their average, weighted by the sentence frequency of each word.
#
# We then use the cosine to calculate the similarity between two sentence embeddings.

# %%
from sklearn.metrics.pairwise import cosine_similarity
from collections import Counter
import math

def run_avg_benchmark(sentences1, sentences2, model=None, use_stoplist=False, doc_freqs=None): 

    if doc_freqs is not None:
        N = doc_freqs["NUM_DOCS"]
    
    sims = []
    for (sent1, sent2) in zip(sentences1, sentences2):
    
        tokens1 = sent1.tokens_without_stop if use_stoplist else sent1.tokens
        tokens2 = sent2.tokens_without_stop if use_stoplist else sent2.tokens

        tokens1 = [token for token in tokens1 if token in model]
        tokens2 = [token for token in tokens2 if token in model]
        
        if len(tokens1) == 0 or len(tokens2) == 0:
            sims.append(0)
            continue
        
        tokfreqs1 = Counter(tokens1)
        tokfreqs2 = Counter(tokens2)
        
        weights1 = [tokfreqs1[token] * math.log(N/(doc_freqs.get(token, 0)+1)) 
                    for token in tokfreqs1] if doc_freqs else None
        weights2 = [tokfreqs2[token] * math.log(N/(doc_freqs.get(token, 0)+1)) 
                    for token in tokfreqs2] if doc_freqs else None
        
        if weights1 and weights2:
            if sum(weights1) == 0 or sum(weights2) == 0:
                sims.append(0)
                continue
        embedding1 = np.average([model[token] for token in tokfreqs1], axis=0, weights=weights1).reshape(1, -1)
        embedding2 = np.average([model[token] for token in tokfreqs2], axis=0, weights=weights2).reshape(1, -1)

        sim = cosine_similarity(embedding1, embedding2)[0][0]
        sims.append(sim)

    return sims

# %% [markdown]
# ### Word Mover's Distance
#
# Word mover's distance is a popular alternative to the simple average embedding similarity. The Word Mover's Distance uses the word embeddings of the words in two texts to measure the minimum amount that the words in one text need to "travel" in semantic space to reach the words of the other text. Word mover's distance is available in the popular Gensim library.

# %%
def run_wmd_benchmark(sentences1, sentences2, model, use_stoplist=False):
    
    sims = []
    for (sent1, sent2) in zip(sentences1, sentences2):
    
        tokens1 = sent1.tokens_without_stop if use_stoplist else sent1.tokens
        tokens2 = sent2.tokens_without_stop if use_stoplist else sent2.tokens
        
        tokens1 = [token for token in tokens1 if token in model]
        tokens2 = [token for token in tokens2 if token in model]
        
        if len(tokens1) == 0 or len(tokens2) == 0:
            tokens1 = [token for token in sent1.tokens if token in model]
            tokens2 = [token for token in sent2.tokens if token in model]
            
        sims.append(-model.wmdistance(tokens1, tokens2))
        
    return sims

# %% [markdown]
# ### Smooth Inverse Frequency
#
# Taking the average of the word embeddings in a sentence, like we did above, is a very crude method of computing sentence embeddings. Most importantly, this gives far too much weight to words that are quite irrelevant, semantically speaking. Smooth Inverse Frequency tries to solve this problem.
#
# To compute SIF sentence embeddings, we first compute a weighted average of the token embeddings in the sentence. This procedure is very similar to the weighted average we used above, with the single difference that the word embeddings are weighted by `a/a+p(w)`, where `w` is a parameter that is set to `0.001` by default, and `p(w)` is the estimated relative frequency of a word in a reference corpus.

# %% [markdown]
# Next, we need to perform common component removal: we compute the principal component of the sentence embeddings we obtained above and subtract from them their projections on this first principal component. This corrects for the influence of high-frequency words that mostly have a syntactic or discourse function, such as "just", "there", "but", etc.

# %%
from sklearn.decomposition import TruncatedSVD

def remove_first_principal_component(X):
    svd = TruncatedSVD(n_components=1, n_iter=7, random_state=0)
    svd.fit(X)
    pc = svd.components_
    XX = X - X.dot(pc.transpose()) * pc
    return XX


def run_sif_benchmark(sentences1, sentences2, model, freqs={}, use_stoplist=False, a=0.001): 
    total_freq = sum(freqs.values())
    embeddings = []
    
    # SIF requires us to first collect all sentence embeddings and then perform 
    # common component analysis.
    for (sent1, sent2) in zip(sentences1, sentences2): 
        
        tokens1 = sent1.tokens_without_stop if use_stoplist else sent1.tokens
        tokens2 = sent2.tokens_without_stop if use_stoplist else sent2.tokens   
        
        tokens1 = [token for token in tokens1 if token in model]
        tokens2 = [token for token in tokens2 if token in model]
        
        if tokens1 == []: tokens1 = ['empty']
        if tokens2 == []: tokens2 = ['empty'] 
        
        weights1 = [a/(a+freqs.get(token,0)/total_freq) for token in tokens1]
        weights2 = [a/(a+freqs.get(token,0)/total_freq) for token in tokens2]
        
        embedding1 = np.average([model[token] for token in tokens1], axis=0, weights=weights1)
        embedding2 = np.average([model[token] for token in tokens2], axis=0, weights=weights2)
        embeddings.append(embedding1)
        embeddings.append(embedding2)

            
        
        
    embeddings = remove_first_principal_component(np.array(embeddings))
    sims = [cosine_similarity(embeddings[idx*2].reshape(1, -1), 
                              embeddings[idx*2+1].reshape(1, -1))[0][0] 
            for idx in range(int(len(embeddings)/2))]

    return sims

# %% [markdown]
# The methods above share two important characteristics:
#
# - As simple bag-of-word methods, they do take not word order into account.
# - The word embeddings they use have been learned in an unsupervised manner.
#
# Both these characteristics are potential downsides:
#
# - Since differences in word order can point to differences in meaning (compare `the dog bites the man` with `the man bites the dog`), we'd like our sentence embeddings to be sensitive to this variation.
# - Supervised training can help sentence embeddings learn the meaning of a sentence more directly.

# %% [markdown]
# ## Experiments

# %%
def run_experiment(df, benchmarks): 
    
    sentences1 = [Sentence(s) for s in df['sent_1']]
    sentences2 = [Sentence(s) for s in df['sent_2']]
    
    pearson_cors, spearman_cors = [], []
    for label, method in benchmarks:
        sims = method(sentences1, sentences2)
        pearson_correlation = scipy.stats.pearsonr(sims, df['sim'])[0]
        print(label, pearson_correlation)
        pearson_cors.append(pearson_correlation)
        spearman_correlation = scipy.stats.spearmanr(sims, df['sim'])[0]
        spearman_cors.append(spearman_correlation)
        
    return pearson_cors, spearman_cors

# %%
import functools as ft

benchmarks = [("AVG-W2V", ft.partial(run_avg_benchmark, model=word2vec, use_stoplist=False)),
              ("AVG-W2V-STOP", ft.partial(run_avg_benchmark, model=word2vec, use_stoplist=True)),
              ("AVG-W2V-TFIDF", ft.partial(run_avg_benchmark, model=word2vec, use_stoplist=False, doc_freqs=doc_frequencies)),
              ("AVG-W2V-TFIDF-STOP", ft.partial(run_avg_benchmark, model=word2vec, use_stoplist=True, doc_freqs=doc_frequencies)),
              ("WMD-W2V", ft.partial(run_wmd_benchmark, model=word2vec, use_stoplist=False)), 
              ("SIF-W2V", ft.partial(run_sif_benchmark, freqs=frequencies, model=word2vec, use_stoplist=False)),
             ]

global PYEMD_EXT

# %% [markdown]
# # Application to our dataset - simple version

# %%
# data = pd.read_csv('Example_dataset_marble - 5_column_with_correct.csv')
data = pd.read_csv('Example_dataset_marble_v2 - 2_data_no_omission.csv')

# %% [markdown]
# ## Match the sentences

# %%
def run_all_match(df, model, benchmarks): 
    size = len(model.index)
    text_frame = df.copy()
    sims = {"stud_sentence":[],
            "stud_field":[],}
    for label, method in benchmarks:
        sims[label+"_all_scores"] = []
        sims[label+"_similarity"] = []
        sims[label+"_aimed_sentence"] = []
        sims[label+"_aimed_field"] = []
        
    for index, row in text_frame.iterrows():
        stud_sentence = row["Field_en"]
        sims["stud_sentence"].append(stud_sentence)
        sims["stud_field"].append(row["Fieldname"])
        student_sentences = [Sentence(stud_sentence)]*size
        model_sentences = model[row['Category']].apply(lambda s: Sentence(s))
    #   pearson_cors, spearman_cors = [], []
        for label, method in benchmarks:
            similarity_scores = method(student_sentences, model_sentences)
            similarity = max(similarity_scores)
            index = np.argmax(similarity_scores)
            aimed_sentence = model_sentences.iloc[index]
            aimed_field = model_sentences.index[index]
            sims[label+"_all_scores"].append(similarity_scores)
            sims[label+"_similarity"].append(similarity)
            sims[label+"_aimed_sentence"].append(aimed_sentence.raw)
            sims[label+"_aimed_field"].append(aimed_field)
    frame = pd.DataFrame(sims)
    return frame

# %%
model_frame = pd.read_csv('correct_answers.csv', index_col=0)
exp_frame2 = data.copy()
# For old dataset
# exp_frame2['Category'] = [tab[0] for tab in exp_frame2['Fieldname'].str.split(";")]
model_frame = model_frame[[ 'Field1_en', 'Field2_en','Field3_en', 'Field4_en']]
model_frame = model_frame.transpose()
model_frame.head()
# Out:
# TextName                   Beton  \
# Field1_en        Central heating
# Field2_en     Concrete dries out
# Field3_en  Buildings are smaller
# Field4_en  Elevators Bliven hang
#
# TextName                                               Botox  \
# Field1_en                  Can help prevent muscle tightness
# Field2_en  Can help against wrinkles between the eyes and...
# Field3_en                                People look younger
# Field4_en                       Facial expression can change
#
# TextName                                                Geld  \
# Field1_en  People should not be distracted for too long risk
# Field2_en  A person may experience only short deep happin...
# Field3_en                          People get used to luxury
# Field4_en                  Money does not gellukig long time
#
# TextName                                               Metro  \
# Field1_en            Waste need not be processed in some way
# Field2_en                        Artificial reef constructed
# Field3_en                     More plankton and marine fauna
# Field4_en  More fish (such as mackerel, grouper, sea fish...
#
# TextName                                Muziek  \
# Field1_en         learn to read and play music
# Field2_en  Improving mathematics vaardigheiten
# Field3_en     Can help bring back old memories
# Field4_en            Higher scores on IQ tests
#
# TextName                                            Suez
# Field1_en     No natural connection Western Indian Ocean
# Field2_en  Ships make long trip around African continent
# Field3_en                        Shorter waterway needed
# Field4_en                                 Suez canal dug

# %%
frame_sim2 = run_all_match(exp_frame2, model_frame, benchmarks)
frame_sim2
# Out:
#                                           stud_sentence  stud_field  \
# 0                                   elevators get stuck           1
# 1                      Concrete shrinks as the hot word           1
# 2                       By heating the concrete shrinks           1
# 3          concrete buildings shrink by central heating           1
# 4                      concrete decreases after a while           1
# 5                                   can shrink concrete           1
# 6                             shrink concrete buildings           1
# 7     Buildings made of concrete but people did not ...           1
# 8                       Concrete shrinks as it gets hot           1
# 9              v concrete buildings become smaller heat           1
# 10                       get small concrete as it dries           1
# 11                                  can shrink concrete           1
# 12               The central heating dries out concrete           1
# 13                                     concrete shrinks           1
# 14                           Concrete can dry out by CV           1
# 15                                            dries out           1
# 16                     concrete drying by using heating           1
# 17                      using the CV concrete dries out           1
# 18                central heating in concrete buildings           1
# 19                      in many buildings thermal plant           1
# 20         concrete shrinkage by use of central heating           1
# 21     heating in concrete buildings can cause problems           1
# 22         in a (concrete) buildings is increasingly CV           1
# 23                        concrete shrinkage by heating           1
# 24      Many buildings have a resume that radiates heat           1
# 25    if buildings are not inspected at all of concr...           1
# 26                      Concrete buildings with heating           1
# 27    concrete buildings were built where central he...           1
# 28                                           by heating           1
# 29                 central heating in concrete building           1
# ...                                                 ...         ...
# 1755                                       less expense           4
# 1756  channel connection between the Mediterranean a...           4
# 1757                              Now not around Africa           4
# 1758                           they made the Suez Canal           4
# 1759                                shorter trade route           4
# 1760                                     Suez canal dug           4
# 1761                     Hoefen ships not ignore Africa           4
# 1762                                   Sueskanaal built           4
# 1763                             the channel was opened           4
# 1764               of 10000+ nm to 6538 nm to Rotterdam           4
# 1765                                 the Suez Canal was           4
# 1766                            Suez canal construction           4
# 1767                     the distance is reduced by 40%           4
# 1768                             The Suez Canal was dug           4
# 1769                                     dug Suez Canal           4
# 1770                people do not a large piece of land           4
# 1771                       the trip is shortened by 40%           4
# 1772    Trade does not have the whole African continent           4
# 1773                                       channel open           4
# 1774               they built the Suez canal eventually           4
# 1775                  boats sail through the Suez canal           4
# 1776                                 Can you underneath           4
# 1777                 the Suez canal was dug by laborers           4
# 1778                          the Suez Canal was opened           4
# 1779     more transportation and much shorter distances           4
# 1780               a channel that shortens the distance           4
# 1781                    habituation to money and luxury           4
# 1782                           many distances shortened           4
# 1783                                      zeemiles less           4
# 1784               Suez Canal opened in 1842 scheepsweg           4
#
#                                      AVG-W2V_all_scores  AVG-W2V_similarity  \
# 0      [0.23129374, 0.29224274, 0.34695882, 0.79110837]            0.791108
# 1        [0.3182352, 0.6590791, 0.29467282, 0.23470604]            0.659079
# 2        [0.6045574, 0.6163491, 0.42220408, 0.20660926]            0.616349
# 3        [0.7154844, 0.50241363, 0.6070077, 0.32110387]            0.715484
# 4      [0.22756946, 0.54321146, 0.36083493, 0.21276176]            0.543211
# 5      [0.23453128, 0.64097226, 0.41722053, 0.23415516]            0.640972
# 6        [0.2919688, 0.55790967, 0.6356981, 0.34406978]            0.635698
# 7        [0.34320924, 0.5560944, 0.5448593, 0.35445443]            0.556094
# 8       [0.31951603, 0.6859616, 0.32092375, 0.23010294]            0.685962
# 9         [0.3873139, 0.5093604, 0.6470331, 0.34160417]            0.647033
# 10        [0.28490314, 0.84757674, 0.412391, 0.2937765]            0.847577
# 11     [0.23453128, 0.64097226, 0.41722053, 0.23415516]            0.640972
# 12      [0.71555144, 0.8389427, 0.34963578, 0.26021165]            0.838943
# 13      [0.23712553, 0.7028816, 0.34942183, 0.17413981]            0.702882
# 14      [0.21329139, 0.6146025, 0.28659904, 0.14644729]            0.614603
# 15     [0.20107125, 0.86244774, 0.16264643, 0.16411532]            0.862448
# 16       [0.59871364, 0.6413393, 0.32711747, 0.2305709]            0.641339
# 17      [0.24202983, 0.7619919, 0.25046667, 0.15821314]            0.761992
# 18        [0.7720704, 0.49576437, 0.5721931, 0.3324805]            0.772070
# 19       [0.3917085, 0.30067667, 0.5623895, 0.27893806]            0.562389
# 20       [0.702083, 0.49400607, 0.42857113, 0.25663164]            0.702083
# 21        [0.57818824, 0.5373807, 0.5585535, 0.3464049]            0.578188
# 22       [0.29419208, 0.399791, 0.55295616, 0.21682051]            0.552956
# 23      [0.56612206, 0.5348792, 0.37534177, 0.22389041]            0.566122
# 24      [0.40900692, 0.40668598, 0.5647773, 0.38318485]            0.564777
# 25       [0.51543313, 0.5313027, 0.6143882, 0.39608762]            0.614388
# 26       [0.61999595, 0.5264568, 0.58896935, 0.3639283]            0.619996
# 27        [0.673175, 0.4917728, 0.65013444, 0.38811088]            0.673175
# 28      [0.7568707, 0.22142787, 0.27638188, 0.14835058]            0.756871
# 29         [0.7900608, 0.5219312, 0.457846, 0.28794965]            0.790061
# ...                                                 ...                 ...
# 1755  [0.15516827, 0.24377489, 0.26350313, 0.0002573...            0.263503
# 1756      [0.7862538, 0.5046602, 0.30622286, 0.3223536]            0.786254
# 1757    [0.44478005, 0.6276505, 0.22112006, 0.07422346]            0.627650
# 1758       [0.4271776, 0.4078592, 0.5350049, 0.6590285]            0.659028
# 1759   [0.18115744, 0.39723033, 0.62335646, 0.19554798]            0.623356
# 1760      [0.28646868, 0.1616168, 0.4121194, 1.0000001]            1.000000
# 1761   [0.45629215, 0.65105206, 0.27112284, 0.09815072]            0.651052
# 1762   [0.15443823, 0.13028944, 0.13859491, 0.29464716]            0.294647
# 1763   [0.22169021, 0.22657396, 0.20723279, 0.29991812]            0.299918
# 1764  [0.09508865, 0.13671191, 0.14857104, -0.009860...            0.148571
# 1765      [0.37845623, 0.2860643, 0.468249, 0.68791974]            0.687920
# 1766     [0.2956739, 0.18144341, 0.4356319, 0.69531304]            0.695313
# 1767   [0.2775809, 0.32650673, 0.28928775, 0.072525635]            0.326507
# 1768   [0.33598855, 0.24452145, 0.41061607, 0.89669365]            0.896694
# 1769      [0.28646868, 0.1616168, 0.4121194, 1.0000001]            1.000000
# 1770     [0.428091, 0.42616206, 0.29987198, 0.18373366]            0.428091
# 1771    [0.2198046, 0.45278093, 0.33204535, 0.09901881]            0.452781
# 1772   [0.44384143, 0.7363279, 0.27378607, 0.086369276]            0.736328
# 1773     [0.2104753, 0.20528635, 0.23297542, 0.2674635]            0.267464
# 1774     [0.37739015, 0.3494198, 0.50440764, 0.6476529]            0.647653
# 1775      [0.36115804, 0.452955, 0.49642617, 0.5424415]            0.542441
# 1776   [0.31497163, 0.33312646, 0.28916255, 0.17684822]            0.333126
# 1777    [0.29441634, 0.26743028, 0.3420924, 0.76334643]            0.763346
# 1778   [0.31029803, 0.24804258, 0.40058586, 0.64488655]            0.644887
# 1779     [0.26983047, 0.4037763, 0.6277314, 0.11351707]            0.627731
# 1780   [0.31147325, 0.35102984, 0.48975626, 0.17537782]            0.489756
# 1781   [0.2887781, 0.21509375, 0.23240395, 0.123384744]            0.288778
# 1782    [0.2002056, 0.36677793, 0.47754154, 0.08864382]            0.477542
# 1783  [0.14437187, 0.19476722, 0.3639042, -0.012983156]            0.363904
# 1784    [0.3026226, 0.22684053, 0.41750756, 0.68055135]            0.680551
#
#                              AVG-W2V_aimed_sentence AVG-W2V_aimed_field  \
# 0                             Elevators Bliven hang           Field4_en
# 1                                Concrete dries out           Field2_en
# 2                                Concrete dries out           Field2_en
# 3                                   Central heating           Field1_en
# 4                                Concrete dries out           Field2_en
# 5                                Concrete dries out           Field2_en
# 6                             Buildings are smaller           Field3_en
# 7                                Concrete dries out           Field2_en
# 8                                Concrete dries out           Field2_en
# 9                             Buildings are smaller           Field3_en
# 10                               Concrete dries out           Field2_en
# 11                               Concrete dries out           Field2_en
# 12                               Concrete dries out           Field2_en
# 13                               Concrete dries out           Field2_en
# 14                               Concrete dries out           Field2_en
# 15                               Concrete dries out           Field2_en
# 16                               Concrete dries out           Field2_en
# 17                               Concrete dries out           Field2_en
# 18                                  Central heating           Field1_en
# 19                            Buildings are smaller           Field3_en
# 20                                  Central heating           Field1_en
# 21                                  Central heating           Field1_en
# 22                            Buildings are smaller           Field3_en
# 23                                  Central heating           Field1_en
# 24                            Buildings are smaller           Field3_en
# 25                            Buildings are smaller           Field3_en
# 26                                  Central heating           Field1_en
# 27                                  Central heating           Field1_en
# 28                                  Central heating           Field1_en
# 29                                  Central heating           Field1_en
# ...                                             ...                 ...
# 1755                        Shorter waterway needed           Field3_en
# 1756     No natural connection Western Indian Ocean           Field1_en
# 1757  Ships make long trip around African continent           Field2_en
# 1758                                 Suez canal dug           Field4_en
# 1759                        Shorter waterway needed           Field3_en
# 1760                                 Suez canal dug           Field4_en
# 1761  Ships make long trip around African continent           Field2_en
# 1762                                 Suez canal dug           Field4_en
# 1763                                 Suez canal dug           Field4_en
# 1764                        Shorter waterway needed           Field3_en
# 1765                                 Suez canal dug           Field4_en
# 1766                                 Suez canal dug           Field4_en
# 1767  Ships make long trip around African continent           Field2_en
# 1768                                 Suez canal dug           Field4_en
# 1769                                 Suez canal dug           Field4_en
# 1770     No natural connection Western Indian Ocean           Field1_en
# 1771  Ships make long trip around African continent           Field2_en
# 1772  Ships make long trip around African continent           Field2_en
# 1773                                 Suez canal dug           Field4_en
# 1774                                 Suez canal dug           Field4_en
# 1775                                 Suez canal dug           Field4_en
# 1776  Ships make long trip around African continent           Field2_en
# 1777                                 Suez canal dug           Field4_en
# 1778                                 Suez canal dug           Field4_en
# 1779                        Shorter waterway needed           Field3_en
# 1780                        Shorter waterway needed           Field3_en
# 1781     No natural connection Western Indian Ocean           Field1_en
# 1782                        Shorter waterway needed           Field3_en
# 1783                        Shorter waterway needed           Field3_en
# 1784                                 Suez canal dug           Field4_en
#
#                                 AVG-W2V-STOP_all_scores  \
# 0      [0.23129374, 0.23140132, 0.29834038, 0.79110837]
# 1        [0.2853224, 0.6482074, 0.19933677, 0.24124703]
# 2        [0.6227552, 0.6746083, 0.33655205, 0.23326936]
# 3             [0.735, 0.52880764, 0.6237523, 0.3444402]
# 4        [0.22310564, 0.6043567, 0.32610884, 0.2073527]
# 5       [0.2236396, 0.63735586, 0.36290738, 0.20726171]
# 6        [0.2919688, 0.5732072, 0.69152117, 0.34406978]
# 7        [0.4059801, 0.58945316, 0.5575507, 0.39485216]
# 8       [0.31247708, 0.6632971, 0.21031305, 0.22528474]
# 9        [0.3873139, 0.49476156, 0.6335725, 0.34160417]
# 10      [0.27189973, 0.8822222, 0.35388577, 0.30036443]
# 11      [0.2236396, 0.63735586, 0.36290738, 0.20726171]
# 12        [0.7433372, 0.8230431, 0.30736604, 0.2554686]
# 13      [0.23712553, 0.72525334, 0.3297347, 0.17413981]
# 14        [0.1879653, 0.5377793, 0.1560774, 0.11893759]
# 15       [0.1841209, 0.8193205, 0.103062145, 0.1405913]
# 16       [0.6139577, 0.6883587, 0.27008188, 0.25241542]
# 17      [0.2027267, 0.71405244, 0.18535966, 0.13655603]
# 18      [0.7674432, 0.49615568, 0.60154426, 0.34168854]
# 19      [0.35745955, 0.27974302, 0.5535196, 0.28052157]
# 20       [0.72934794, 0.5258253, 0.3746791, 0.28183547]
# 21     [0.58279675, 0.49632967, 0.52044344, 0.34799203]
# 22         [0.24073184, 0.38458934, 0.4998, 0.23080437]
# 23      [0.58906084, 0.59588635, 0.31455287, 0.2521157]
# 24      [0.40835804, 0.38056365, 0.48258546, 0.3721213]
# 25       [0.6571578, 0.53364855, 0.5861588, 0.41190428]
# 26      [0.6277616, 0.54264313, 0.60439765, 0.36172947]
# 27       [0.70939493, 0.50029266, 0.6169829, 0.3626918]
# 28     [0.83629066, 0.25847986, 0.17330042, 0.19531989]
# 29        [0.7916084, 0.5257534, 0.4651014, 0.29646468]
# ...                                                 ...
# 1755  [0.09784576, 0.24377489, 0.26350313, 0.0002573...
# 1756    [0.8195433, 0.45058212, 0.23525472, 0.30518958]
# 1757    [0.39007032, 0.5780981, 0.12711388, 0.04857315]
# 1758        [0.3401764, 0.29816, 0.49820003, 0.7146455]
# 1759   [0.13606046, 0.39723033, 0.62335646, 0.19554798]
# 1760       [0.2932113, 0.1616168, 0.4121194, 1.0000001]
# 1761   [0.40733176, 0.63429105, 0.23305982, 0.09194451]
# 1762   [0.13049753, 0.13028944, 0.13859491, 0.29464716]
# 1763   [0.14074025, 0.12930351, 0.16700728, 0.28989446]
# 1764  [0.08887712, 0.13671191, 0.14857104, -0.009860...
# 1765    [0.3532568, 0.18269451, 0.49936584, 0.79226285]
# 1766    [0.31082293, 0.18144341, 0.4356319, 0.69531304]
# 1767    [0.15767197, 0.22777417, 0.2858142, 0.04848696]
# 1768       [0.2932113, 0.1616168, 0.4121194, 1.0000001]
# 1769       [0.2932113, 0.1616168, 0.4121194, 1.0000001]
# 1770    [0.34833702, 0.34089687, 0.2267825, 0.19887906]
# 1771    [0.09630538, 0.3943139, 0.34074745, 0.08353947]
# 1772   [0.38445958, 0.7470138, 0.17020589, 0.058779225]
# 1773     [0.2000883, 0.20528635, 0.23297542, 0.2674635]
# 1774     [0.32137495, 0.2617384, 0.4803144, 0.69975835]
# 1775       [0.3128191, 0.38678053, 0.454479, 0.5323023]
# 1776    [0.17059731, 0.16307719, 0.21019047, 0.3124488]
# 1777    [0.25938675, 0.19220136, 0.3457925, 0.85536236]
# 1778    [0.27165914, 0.16334279, 0.41528568, 0.7275371]
# 1779      [0.2028453, 0.3902819, 0.6063015, 0.12257415]
# 1780    [0.20228355, 0.26510745, 0.4413882, 0.13715924]
# 1781  [0.26246285, 0.21509375, 0.23240395, 0.123384744]
# 1782    [0.1602767, 0.36677793, 0.47754154, 0.08864382]
# 1783  [0.07548753, 0.19476722, 0.3639042, -0.012983156]
# 1784    [0.27165914, 0.16334279, 0.41528568, 0.7275371]
#
#       AVG-W2V-STOP_similarity                    AVG-W2V-STOP_aimed_sentence  \
# 0                    0.791108                          Elevators Bliven hang
# 1                    0.648207                             Concrete dries out
# 2                    0.674608                             Concrete dries out
# 3                    0.735000                                Central heating
# 4                    0.604357                             Concrete dries out
# 5                    0.637356                             Concrete dries out
# 6                    0.691521                          Buildings are smaller
# 7                    0.589453                             Concrete dries out
# 8                    0.663297                             Concrete dries out
# 9                    0.633573                          Buildings are smaller
# 10                   0.882222                             Concrete dries out
# 11                   0.637356                             Concrete dries out
# 12                   0.823043                             Concrete dries out
# 13                   0.725253                             Concrete dries out
# 14                   0.537779                             Concrete dries out
# 15                   0.819320                             Concrete dries out
# 16                   0.688359                             Concrete dries out
# 17                   0.714052                             Concrete dries out
# 18                   0.767443                                Central heating
# 19                   0.553520                          Buildings are smaller
# 20                   0.729348                                Central heating
# 21                   0.582797                                Central heating
# 22                   0.499800                          Buildings are smaller
# 23                   0.595886                             Concrete dries out
# 24                   0.482585                          Buildings are smaller
# 25                   0.657158                                Central heating
# 26                   0.627762                                Central heating
# 27                   0.709395                                Central heating
# 28                   0.836291                                Central heating
# 29                   0.791608                                Central heating
# ...                       ...                                            ...
# 1755                 0.263503                        Shorter waterway needed
# 1756                 0.819543     No natural connection Western Indian Ocean
# 1757                 0.578098  Ships make long trip around African continent
# 1758                 0.714646                                 Suez canal dug
# 1759                 0.623356                        Shorter waterway needed
# 1760                 1.000000                                 Suez canal dug
# 1761                 0.634291  Ships make long trip around African continent
# 1762                 0.294647                                 Suez canal dug
# 1763                 0.289894                                 Suez canal dug
# 1764                 0.148571                        Shorter waterway needed
# 1765                 0.792263                                 Suez canal dug
# 1766                 0.695313                                 Suez canal dug
# 1767                 0.285814                        Shorter waterway needed
# 1768                 1.000000                                 Suez canal dug
# 1769                 1.000000                                 Suez canal dug
# 1770                 0.348337     No natural connection Western Indian Ocean
# 1771                 0.394314  Ships make long trip around African continent
# 1772                 0.747014  Ships make long trip around African continent
# 1773                 0.267464                                 Suez canal dug
# 1774                 0.699758                                 Suez canal dug
# 1775                 0.532302                                 Suez canal dug
# 1776                 0.312449                                 Suez canal dug
# 1777                 0.855362                                 Suez canal dug
# 1778                 0.727537                                 Suez canal dug
# 1779                 0.606301                        Shorter waterway needed
# 1780                 0.441388                        Shorter waterway needed
# 1781                 0.262463     No natural connection Western Indian Ocean
# 1782                 0.477542                        Shorter waterway needed
# 1783                 0.363904                        Shorter waterway needed
# 1784                 0.727537                                 Suez canal dug
#
#      AVG-W2V-STOP_aimed_field         ...           \
# 0                   Field4_en         ...
# 1                   Field2_en         ...
# 2                   Field2_en         ...
# 3                   Field1_en         ...
# 4                   Field2_en         ...
# 5                   Field2_en         ...
# 6                   Field3_en         ...
# 7                   Field2_en         ...
# 8                   Field2_en         ...
# 9                   Field3_en         ...
# 10                  Field2_en         ...
# 11                  Field2_en         ...
# 12                  Field2_en         ...
# 13                  Field2_en         ...
# 14                  Field2_en         ...
# 15                  Field2_en         ...
# 16                  Field2_en         ...
# 17                  Field2_en         ...
# 18                  Field1_en         ...
# 19                  Field3_en         ...
# 20                  Field1_en         ...
# 21                  Field1_en         ...
# 22                  Field3_en         ...
# 23                  Field2_en         ...
# 24                  Field3_en         ...
# 25                  Field1_en         ...
# 26                  Field1_en         ...
# 27                  Field1_en         ...
# 28                  Field1_en         ...
# 29                  Field1_en         ...
# ...                       ...         ...
# 1755                Field3_en         ...
# 1756                Field1_en         ...
# 1757                Field2_en         ...
# 1758                Field4_en         ...
# 1759                Field3_en         ...
# 1760                Field4_en         ...
# 1761                Field2_en         ...
# 1762                Field4_en         ...
# 1763                Field4_en         ...
# 1764                Field3_en         ...
# 1765                Field4_en         ...
# 1766                Field4_en         ...
# 1767                Field3_en         ...
# 1768                Field4_en         ...
# 1769                Field4_en         ...
# 1770                Field1_en         ...
# 1771                Field2_en         ...
# 1772                Field2_en         ...
# 1773                Field4_en         ...
# 1774                Field4_en         ...
# 1775                Field4_en         ...
# 1776                Field4_en         ...
# 1777                Field4_en         ...
# 1778                Field4_en         ...
# 1779                Field3_en         ...
# 1780                Field3_en         ...
# 1781                Field1_en         ...
# 1782                Field3_en         ...
# 1783                Field3_en         ...
# 1784                Field4_en         ...
#
#                   AVG-W2V-TFIDF-STOP_aimed_sentence  \
# 0                             Elevators Bliven hang
# 1                                Concrete dries out
# 2                                   Central heating
# 3                                   Central heating
# 4                                Concrete dries out
# 5                                Concrete dries out
# 6                             Buildings are smaller
# 7                                Concrete dries out
# 8                                Concrete dries out
# 9                             Buildings are smaller
# 10                               Concrete dries out
# 11                               Concrete dries out
# 12                               Concrete dries out
# 13                               Concrete dries out
# 14                               Concrete dries out
# 15                               Concrete dries out
# 16                                  Central heating
# 17                               Concrete dries out
# 18                                  Central heating
# 19                            Buildings are smaller
# 20                                  Central heating
# 21                                  Central heating
# 22                            Buildings are smaller
# 23                                  Central heating
# 24                                  Central heating
# 25                                  Central heating
# 26                                  Central heating
# 27                                  Central heating
# 28                                  Central heating
# 29                                  Central heating
# ...                                             ...
# 1755  Ships make long trip around African continent
# 1756     No natural connection Western Indian Ocean
# 1757  Ships make long trip around African continent
# 1758                                 Suez canal dug
# 1759                        Shorter waterway needed
# 1760                                 Suez canal dug
# 1761  Ships make long trip around African continent
# 1762                                 Suez canal dug
# 1763                                 Suez canal dug
# 1764                        Shorter waterway needed
# 1765                                 Suez canal dug
# 1766                                 Suez canal dug
# 1767  Ships make long trip around African continent
# 1768                                 Suez canal dug
# 1769                                 Suez canal dug
# 1770     No natural connection Western Indian Ocean
# 1771  Ships make long trip around African continent
# 1772  Ships make long trip around African continent
# 1773                                 Suez canal dug
# 1774                                 Suez canal dug
# 1775                        Shorter waterway needed
# 1776                                 Suez canal dug
# 1777                                 Suez canal dug
# 1778                                 Suez canal dug
# 1779                        Shorter waterway needed
# 1780                        Shorter waterway needed
# 1781     No natural connection Western Indian Ocean
# 1782                        Shorter waterway needed
# 1783                        Shorter waterway needed
# 1784                                 Suez canal dug
#
#       AVG-W2V-TFIDF-STOP_aimed_field  \
# 0                          Field4_en
# 1                          Field2_en
# 2                          Field1_en
# 3                          Field1_en
# 4                          Field2_en
# 5                          Field2_en
# 6                          Field3_en
# 7                          Field2_en
# 8                          Field2_en
# 9                          Field3_en
# 10                         Field2_en
# 11                         Field2_en
# 12                         Field2_en
# 13                         Field2_en
# 14                         Field2_en
# 15                         Field2_en
# 16                         Field1_en
# 17                         Field2_en
# 18                         Field1_en
# 19                         Field3_en
# 20                         Field1_en
# 21                         Field1_en
# 22                         Field3_en
# 23                         Field1_en
# 24                         Field1_en
# 25                         Field1_en
# 26                         Field1_en
# 27                         Field1_en
# 28                         Field1_en
# 29                         Field1_en
# ...                              ...
# 1755                       Field2_en
# 1756                       Field1_en
# 1757                       Field2_en
# 1758                       Field4_en
# 1759                       Field3_en
# 1760                       Field4_en
# 1761                       Field2_en
# 1762                       Field4_en
# 1763                       Field4_en
# 1764                       Field3_en
# 1765                       Field4_en
# 1766                       Field4_en
# 1767                       Field2_en
# 1768                       Field4_en
# 1769                       Field4_en
# 1770                       Field1_en
# 1771                       Field2_en
# 1772                       Field2_en
# 1773                       Field4_en
# 1774                       Field4_en
# 1775                       Field3_en
# 1776                       Field4_en
# 1777                       Field4_en
# 1778                       Field4_en
# 1779                       Field3_en
# 1780                       Field3_en
# 1781                       Field1_en
# 1782                       Field3_en
# 1783                       Field3_en
# 1784                       Field4_en
#
#                                      WMD-W2V_all_scores WMD-W2V_similarity  \
# 0     [-3.5347514412919887, -3.4759544512344434, -3....          -2.028639
# 1     [-3.321185677343309, -2.5409867322305897, -3.1...          -2.540987
# 2     [-2.572935777666521, -2.434328924666586, -3.10...          -2.434329
# 3     [-2.3307194101084705, -2.7974246349678014, -2....          -2.330719
# 4     [-3.3520161573753358, -2.3563450409951607, -3....          -2.356345
# 5     [-3.5564626149292913, -2.1331163235249657, -2....          -2.133116
# 6     [-3.6645448530117775, -2.435029420849517, -2.1...          -2.148722
# 7     [-3.249336135519934, -2.6290873247795004, -2.7...          -2.629087
# 8     [-3.357667595164933, -2.53370519157844, -3.182...          -2.533705
# 9     [-3.585135455515664, -3.1206288802595283, -2.4...          -2.409680
# 10    [-3.265135179135739, -1.879321732783291, -2.94...          -1.879322
# 11    [-3.5564626149292913, -2.1331163235249657, -2....          -2.133116
# 12    [-2.212812645905245, -1.5908384164288472, -3.2...          -1.590838
# 13    [-3.795813587578535, -2.2991790538779364, -3.4...          -2.299179
# 14    [-3.614826927881465, -2.4268976389412753, -3.3...          -2.426898
# 15    [-3.5318392788619994, -1.2587602350948845, -3....          -1.258760
# 16    [-2.5903882712631225, -2.3856519436892563, -3....          -2.385652
# 17    [-3.642150266439499, -1.8664624416582882, -3.4...          -1.866462
# 18    [-1.9599192402517318, -2.656941570882253, -2.5...          -1.959919
# 19    [-3.364631843916321, -3.4302618464930283, -2.5...          -2.537265
# 20    [-2.2910593567243227, -2.803429333962944, -3.1...          -2.291059
# 21    [-2.86006687231348, -2.8535230916964562, -2.67...          -2.678660
# 22    [-3.6167475793730204, -3.021427293976396, -2.6...          -2.697242
# 23    [-2.564411180666685, -2.6087991783254822, -3.2...          -2.564411
# 24    [-3.327405137687315, -3.3537793062489776, -2.6...          -2.687969
# 25    [-2.8530625351130796, -2.9439736296848027, -2....          -2.587643
# 26    [-2.486667771263838, -2.5522444285143884, -2.4...          -2.416177
# 27    [-2.390653213216348, -2.854257998000465, -2.49...          -2.390653
# 28    [-1.367372286881566, -3.3832405945557107, -3.2...          -1.367372
# 29    [-1.856752711294365, -2.545233856962655, -2.93...          -1.856753
# ...                                                 ...                ...
# 1755  [-3.490798855238771, -3.4078508050701553, -3.3...          -3.398543
# 1756  [-1.818584096403503, -3.037035102551941, -3.40...          -1.818584
# 1757  [-3.0326197235368975, -2.539960332940641, -3.4...          -2.539960
# 1758  [-3.085256515922181, -2.9996026317140214, -2.8...          -2.494859
# 1759  [-3.7568117070521083, -3.5348056432508095, -2....          -2.334398
# 1760  [-3.830880957851911, -3.9805465462185756, -3.4...          -0.000000
# 1761  [-3.3687618031357776, -2.642623442615204, -3.6...          -2.642623
# 1762  [-3.529506656137376, -3.5504108231571596, -3.6...          -3.524056
# 1763  [-3.2379992775577184, -3.230084937736401, -3.2...          -3.230085
# 1764  [-4.763203626768227, -4.723378771441869, -4.74...          -4.723379
# 1765  [-3.1475618665914333, -3.212243794177353, -2.7...          -2.208160
# 1766  [-3.6861910063675745, -3.839264377821861, -3.3...          -1.855787
# 1767  [-3.235371140592722, -3.175967364444567, -3.27...          -3.175967
# 1768  [-3.3101949017327703, -3.374325511393661, -3.0...          -1.688581
# 1769  [-3.830880957851911, -3.9805465462185756, -3.4...          -0.000000
# 1770  [-3.091422021870527, -3.1165619289054645, -3.2...          -3.091422
# 1771  [-3.3405937754893995, -2.6961957742562364, -3....          -2.696196
# 1772  [-3.063662255263081, -2.1533031824903914, -3.3...          -2.153303
# 1773  [-3.5287252729014034, -3.4894823197223506, -3....          -3.489482
# 1774  [-3.170558521072971, -3.2083706296302723, -2.9...          -2.667022
# 1775  [-3.476614686279905, -3.2074946350062876, -3.1...          -2.954794
# 1776  [-3.2707720814356946, -3.2480673899302146, -3....          -3.248067
# 1777  [-3.3518232329556827, -3.4076040302520796, -3....          -2.400426
# 1778  [-3.2373069151242704, -3.305243771680795, -2.9...          -2.542434
# 1779  [-3.4904171164536515, -3.3616259507994717, -2....          -2.654835
# 1780  [-3.3388088007284793, -3.3197452239432512, -3....          -3.127522
# 1781  [-3.7521368793834107, -3.8088200748003307, -3....          -3.752137
# 1782  [-3.6179918547261654, -3.5012870071131115, -3....          -3.273390
# 1783  [-3.3432351381778607, -3.2982795673002823, -3....          -3.160859
# 1784  [-3.3503620782210315, -3.3820178322989918, -2....          -2.248285
#
#                              WMD-W2V_aimed_sentence  WMD-W2V_aimed_field  \
# 0                             Elevators Bliven hang            Field4_en
# 1                                Concrete dries out            Field2_en
# 2                                Concrete dries out            Field2_en
# 3                                   Central heating            Field1_en
# 4                                Concrete dries out            Field2_en
# 5                                Concrete dries out            Field2_en
# 6                             Buildings are smaller            Field3_en
# 7                                Concrete dries out            Field2_en
# 8                                Concrete dries out            Field2_en
# 9                             Buildings are smaller            Field3_en
# 10                               Concrete dries out            Field2_en
# 11                               Concrete dries out            Field2_en
# 12                               Concrete dries out            Field2_en
# 13                               Concrete dries out            Field2_en
# 14                               Concrete dries out            Field2_en
# 15                               Concrete dries out            Field2_en
# 16                               Concrete dries out            Field2_en
# 17                               Concrete dries out            Field2_en
# 18                                  Central heating            Field1_en
# 19                            Buildings are smaller            Field3_en
# 20                                  Central heating            Field1_en
# 21                            Buildings are smaller            Field3_en
# 22                            Buildings are smaller            Field3_en
# 23                                  Central heating            Field1_en
# 24                            Buildings are smaller            Field3_en
# 25                            Buildings are smaller            Field3_en
# 26                            Buildings are smaller            Field3_en
# 27                                  Central heating            Field1_en
# 28                                  Central heating            Field1_en
# 29                                  Central heating            Field1_en
# ...                                             ...                  ...
# 1755                        Shorter waterway needed            Field3_en
# 1756     No natural connection Western Indian Ocean            Field1_en
# 1757  Ships make long trip around African continent            Field2_en
# 1758                                 Suez canal dug            Field4_en
# 1759                        Shorter waterway needed            Field3_en
# 1760                                 Suez canal dug            Field4_en
# 1761  Ships make long trip around African continent            Field2_en
# 1762                                 Suez canal dug            Field4_en
# 1763  Ships make long trip around African continent            Field2_en
# 1764  Ships make long trip around African continent            Field2_en
# 1765                                 Suez canal dug            Field4_en
# 1766                                 Suez canal dug            Field4_en
# 1767  Ships make long trip around African continent            Field2_en
# 1768                                 Suez canal dug            Field4_en
# 1769                                 Suez canal dug            Field4_en
# 1770     No natural connection Western Indian Ocean            Field1_en
# 1771  Ships make long trip around African continent            Field2_en
# 1772  Ships make long trip around African continent            Field2_en
# 1773  Ships make long trip around African continent            Field2_en
# 1774                                 Suez canal dug            Field4_en
# 1775                                 Suez canal dug            Field4_en
# 1776  Ships make long trip around African continent            Field2_en
# 1777                                 Suez canal dug            Field4_en
# 1778                                 Suez canal dug            Field4_en
# 1779                        Shorter waterway needed            Field3_en
# 1780                        Shorter waterway needed            Field3_en
# 1781     No natural connection Western Indian Ocean            Field1_en
# 1782                        Shorter waterway needed            Field3_en
# 1783                        Shorter waterway needed            Field3_en
# 1784                                 Suez canal dug            Field4_en
#
#                                      SIF-W2V_all_scores SIF-W2V_similarity  \
# 0     [-0.42876989150511546, -0.41713199814820806, -...          -0.417132
# 1     [-0.4373615985813257, -0.20627541701337732, -0...          -0.206275
# 2     [-0.29814793100933035, -0.20717351499943445, -...          -0.207174
# 3     [0.014344936161292253, -0.21251113820875436, -...           0.014345
# 4     [-0.4465928324582758, -0.2737919524809011, -0....          -0.273792
# 5     [-0.4883548326022325, -0.3876254216481376, -0....          -0.387625
# 6     [-0.47008324415440034, -0.28581387075507525, -...          -0.232762
# 7     [-0.347514051762186, 0.08689016620109082, -0.1...           0.086890
# 8     [-0.45259856836047396, -0.2791829061184914, -0...          -0.279183
# 9     [-0.33967104016863076, -0.18607466259306052, -...          -0.054580
# 10    [-0.5283672859070571, 0.3870961435510575, -0.4...           0.387096
# 11    [-0.4883548326022325, -0.3876254216481378, -0....          -0.387625
# 12    [-0.019447720328716476, 0.4324840007920061, -0...           0.432484
# 13    [-0.5153285817764975, -0.5302947609193452, -0....          -0.492923
# 14    [-0.49808452214211113, -0.4942089750233788, -0...          -0.494209
# 15    [-0.5365393962317192, -0.6729916669424665, -0....          -0.536539
# 16    [-0.25108511398093114, -0.1275630185859741, -0...          -0.127563
# 17    [-0.5071749894681004, -0.41705273841642504, -0...          -0.417053
# 18    [0.02190397889437676, -0.2839864212763839, -0....           0.021904
# 19    [-0.4806795854489187, -0.46161482261102305, -0...          -0.461615
# 20    [-0.05076147056253019, -0.20892725769690756, -...          -0.050761
# 21    [-0.175181614330535, -0.21272489191587618, -0....          -0.175182
# 22    [-0.48142143344816213, -0.44856996131905047, -...          -0.448570
# 23    [-0.3523028948206478, -0.3070793981140711, -0....          -0.307079
# 24    [-0.3252611753141686, -0.3111734766617433, -0....          -0.300983
# 25    [-0.02932582321871176, -0.06970961679053347, -...          -0.029326
# 26    [-0.20867040988848234, -0.2671584483676236, -0...          -0.208670
# 27    [0.018836799277999097, -0.2233014892003702, -0...           0.018837
# 28    [-0.5849589239505825, -0.5072719215499544, -0....          -0.507272
# 29    [0.03552041193382428, -0.24725282680587785, -0...           0.035520
# ...                                                 ...                ...
# 1755  [-0.5775653083566199, -0.6081242815396616, -0....          -0.577565
# 1756  [0.2359329107746217, -0.09320508915072206, -0....           0.235933
# 1757  [-0.5514529180520729, -0.47382165701312656, -0...          -0.473822
# 1758  [-0.2276283024194973, -0.18416539781209287, -0...          -0.184165
# 1759  [-0.469582334962747, -0.2978206889568444, -0.6...          -0.297821
# 1760  [-0.5740352441377874, -0.5767036310793127, -0....           1.000000
# 1761  [-0.5327801765342566, -0.4420223717218207, -0....          -0.442022
# 1762  [-0.44892186069101886, -0.33884040729262854, -...          -0.338840
# 1763  [-0.42132068609431705, -0.31886553310370813, -...          -0.318866
# 1764  [-0.6170380285616949, -0.6967015881829097, -0....          -0.379467
# 1765  [-0.29292211918731675, -0.3077559920096382, -0...          -0.292922
# 1766  [-0.3184369766469833, -0.28876680745819777, -0...          -0.288767
# 1767  [-0.47723587188843647, -0.4079107286763926, -0...          -0.407911
# 1768  [-0.55736792876767, -0.552558938937682, -0.881...           0.753615
# 1769  [-0.5740352441377874, -0.5767036310793127, -0....           1.000000
# 1770  [-0.11937486947164865, -0.03481638085779185, -...          -0.034816
# 1771  [-0.49265829701269076, -0.35869732068348525, -...          -0.358697
# 1772  [-0.4658755860096019, -0.20764569923468162, -0...          -0.207646
# 1773  [-0.4404309835809291, -0.34696214190874713, -0...          -0.346962
# 1774  [-0.24917564531943942, -0.1803055191118345, -0...          -0.180306
# 1775  [-0.3406776468242801, -0.15353094337295894, -0...          -0.153531
# 1776  [-0.4321965889918681, -0.3402405028823352, -0....          -0.340241
# 1777  [-0.3659649063781689, -0.25387416681507446, -0...          -0.253874
# 1778  [-0.3286032317637104, -0.28585727952054396, -0...          -0.285857
# 1779  [-0.44303585704594156, -0.32698540554430355, -...          -0.326985
# 1780  [-0.46764834361685176, -0.40552794049748186, -...          -0.405528
# 1781  [-0.5189209756160771, -0.44332447293354865, -0...          -0.443324
# 1782  [-0.5046752661819653, -0.4517547399793335, -0....          -0.451755
# 1783  [-0.5217302909315608, -0.5575652127595188, -0....          -0.521730
# 1784  [-0.3330451217070491, -0.2913567881698389, -0....          -0.291357
#
#                              SIF-W2V_aimed_sentence  SIF-W2V_aimed_field
# 0                                Concrete dries out            Field2_en
# 1                                Concrete dries out            Field2_en
# 2                                Concrete dries out            Field2_en
# 3                                   Central heating            Field1_en
# 4                                Concrete dries out            Field2_en
# 5                                Concrete dries out            Field2_en
# 6                             Buildings are smaller            Field3_en
# 7                                Concrete dries out            Field2_en
# 8                                Concrete dries out            Field2_en
# 9                             Buildings are smaller            Field3_en
# 10                               Concrete dries out            Field2_en
# 11                               Concrete dries out            Field2_en
# 12                               Concrete dries out            Field2_en
# 13                            Buildings are smaller            Field3_en
# 14                               Concrete dries out            Field2_en
# 15                                  Central heating            Field1_en
# 16                               Concrete dries out            Field2_en
# 17                               Concrete dries out            Field2_en
# 18                                  Central heating            Field1_en
# 19                               Concrete dries out            Field2_en
# 20                                  Central heating            Field1_en
# 21                                  Central heating            Field1_en
# 22                               Concrete dries out            Field2_en
# 23                               Concrete dries out            Field2_en
# 24                            Buildings are smaller            Field3_en
# 25                                  Central heating            Field1_en
# 26                                  Central heating            Field1_en
# 27                                  Central heating            Field1_en
# 28                               Concrete dries out            Field2_en
# 29                                  Central heating            Field1_en
# ...                                             ...                  ...
# 1755     No natural connection Western Indian Ocean            Field1_en
# 1756     No natural connection Western Indian Ocean            Field1_en
# 1757  Ships make long trip around African continent            Field2_en
# 1758  Ships make long trip around African continent            Field2_en
# 1759  Ships make long trip around African continent            Field2_en
# 1760                                 Suez canal dug            Field4_en
# 1761  Ships make long trip around African continent            Field2_en
# 1762  Ships make long trip around African continent            Field2_en
# 1763  Ships make long trip around African continent            Field2_en
# 1764                                 Suez canal dug            Field4_en
# 1765     No natural connection Western Indian Ocean            Field1_en
# 1766  Ships make long trip around African continent            Field2_en
# 1767  Ships make long trip around African continent            Field2_en
# 1768                                 Suez canal dug            Field4_en
# 1769                                 Suez canal dug            Field4_en
# 1770  Ships make long trip around African continent            Field2_en
# 1771  Ships make long trip around African continent            Field2_en
# 1772  Ships make long trip around African continent            Field2_en
# 1773  Ships make long trip around African continent            Field2_en
# 1774  Ships make long trip around African continent            Field2_en
# 1775  Ships make long trip around African continent            Field2_en
# 1776  Ships make long trip around African continent            Field2_en
# 1777  Ships make long trip around African continent            Field2_en
# 1778  Ships make long trip around African continent            Field2_en
# 1779  Ships make long trip around African continent            Field2_en
# 1780  Ships make long trip around African continent            Field2_en
# 1781  Ships make long trip around African continent            Field2_en
# 1782  Ships make long trip around African continent            Field2_en
# 1783     No natural connection Western Indian Ocean            Field1_en
# 1784  Ships make long trip around African continent            Field2_en
#
# [1785 rows x 26 columns]

# %%
frame_sim2 = pd.concat([frame_sim2, 
                        exp_frame2[['IDStud', 'IDClass', 
                                    "Category","Accuracy_score",
                                    "Code","Fieldname"]]], axis=1)

# %%
frame_sim2.to_csv("complete_result_matched.csv")
sif_matched = frame_sim2[["SIF-W2V_aimed_sentence", 
            "SIF-W2V_aimed_field", 
            'SIF-W2V_similarity',
            'stud_field',
            'stud_sentence',
            'IDStud', 'IDClass', 
            "Category","Accuracy_score",
            "Code","Fieldname"]].copy()
sif_matched.to_csv("sif_wv2_matched.csv")
avg_w2v_matched = frame_sim2[["AVG-W2V_aimed_sentence", 
            "AVG-W2V_aimed_field", 
            'AVG-W2V_similarity',
            'stud_field',
            'stud_sentence',
            'IDStud', 'IDClass', 
            "Category","Accuracy_score",
            "Code","Fieldname"]].copy()
avg_w2v_matched.to_csv("avg_wv2_matched.csv")
