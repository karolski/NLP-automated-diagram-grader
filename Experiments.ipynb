# %% [markdown]
# ## Notebook for experimenting on diagrams dataset

# %%
import pandas as pd
from numpy import vectorize
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Experiments.ipynb',
#  'Example_dataset_marble - 5_column_with_correct.csv']

# %%
frame = pd.read_csv('Example_dataset_marble - 5_column_with_correct.csv')
frame
# Out:
#                                                   Field         Field_correct  \
# 0                               liften gaan vast zitten   Centrale verwarming
# 1                        Beton krimpt als het warm word   Centrale verwarming
# 2          Door de centrale verwarming krimpt het beton   Centrale verwarming
# 3     betonnen gebouwen krimpen bij centrale verwarming   Centrale verwarming
# 4                     beton wordt na een tijdje kleiner   Centrale verwarming
# 5                                     beton kan krimpen   Centrale verwarming
# 6                             betonnen gebouwen krimpen   Centrale verwarming
# 7     Gebouwen worden van beton gemaakt maar mensen ...   Centrale verwarming
# 8                       Beton krimpt als het warm wordt   Centrale verwarming
# 9           gebouwen v beton worden kleiner door warmte   Centrale verwarming
# 10                     beton word kleine als het droogt   Centrale verwarming
# 11                                    beton kan krimpen   Centrale verwarming
# 12         Door de centrale verwarming droogt beton uit   Centrale verwarming
# 13                                         beton krimpt   Centrale verwarming
# 14                          Beton kan door CV uitdrogen   Centrale verwarming
# 15                                           droogt uit   Centrale verwarming
# 16     beton uitdrogen door gebruik centrale verwarming   Centrale verwarming
# 17      door het gebruik van de CV droogt het beton uit   Centrale verwarming
# 18             centrale verwarming in betonnen gebouwen   Centrale verwarming
# 19                  in veel gebouwen warmte-installatie   Centrale verwarming
# 20      betonkrimp door gebruik van centrale verwarming   Centrale verwarming
# 21    verwarming in betonnen gebouwen kan problemen ...   Centrale verwarming
# 22       in een (betonnen) gebouwen zit steeds vaker CV   Centrale verwarming
# 23               betonkrimp door verwarmingsinstallatie   Centrale verwarming
# 24     Veel gebouwen hebben een cv die hitte uitstraalt   Centrale verwarming
# 25    als gebouwen helemaal van niet gekeurd beton z...   Centrale verwarming
# 26                     Betonnen gebouwen met verwarming   Centrale verwarming
# 27    betonnen gebouwen werden gebouwd waar centrale...   Centrale verwarming
# 28                                      door verwarming   Centrale verwarming
# 29              centrale verwarming in gebouw van beton   Centrale verwarming
# ...                                                 ...                   ...
# 1755                                       minder koste  Suez kanaal gegraven
# 1756  kanaalverbinding tussen de middellandse zee en...  Suez kanaal gegraven
# 1757                             nu niet om Afrika heen  Suez kanaal gegraven
# 1758                         ze maakten het suez-kanaal  Suez kanaal gegraven
# 1759                                 Kortere handelsweg  Suez kanaal gegraven
# 1760                               suez kanaal gegraven  Suez kanaal gegraven
# 1761            hoefen schepen niet meer om afrika heen  Suez kanaal gegraven
# 1762                                 Sueskanaal gebouwd  Suez kanaal gegraven
# 1763                            werd het kanaal geopend  Suez kanaal gegraven
# 1764  van 10000+ zeemijl naar 6538 zeemijl naar Rott...  Suez kanaal gegraven
# 1765                        werd het Suezkanaal gemaakt  Suez kanaal gegraven
# 1766                                  aanleg suezkanaal  Suez kanaal gegraven
# 1767                      is de afstand met 40% verkort  Suez kanaal gegraven
# 1768                       Het Suezkanaal werd gegraven  Suez kanaal gegraven
# 1769                                Suezkanaal gegraven  Suez kanaal gegraven
# 1770  hoeven mensen niet meer een groot stuk over he...  Suez kanaal gegraven
# 1771                         is de reis met 40% verkort  Suez kanaal gegraven
# 1772  handel hoeft niet het hele afrikaanse continen...  Suez kanaal gegraven
# 1773                                     kanaal geopend  Suez kanaal gegraven
# 1774        Bouwden zij het suezkanaal uiteindelijk ook  Suez kanaal gegraven
# 1775        kunnen boten door het suezkanaal heen varen  Suez kanaal gegraven
# 1776                               Kan je er onder door  Suez kanaal gegraven
# 1777        het suezkanaal werd gegraven door arbeiders  Suez kanaal gegraven
# 1778                        werd het Suezkanaal geopend  Suez kanaal gegraven
# 1779             meer vervoer en veel kortere afstanden  Suez kanaal gegraven
# 1780                 een kanaal dat het afstand verkort  Suez kanaal gegraven
# 1781                         gewenning aan geld en luxe  Suez kanaal gegraven
# 1782                             veel afstanden verkort  Suez kanaal gegraven
# 1783                                    zeemiles minder  Suez kanaal gegraven
# 1784          suezkanaal geopend als scheepsweg in 1842  Suez kanaal gegraven
#
#                                                Field_en Field_correct_en  \
# 0                                   elevators get stuck  Central heating
# 1                      Concrete shrinks as the hot word  Central heating
# 2                       By heating the concrete shrinks  Central heating
# 3          concrete buildings shrink by central heating  Central heating
# 4                      concrete decreases after a while  Central heating
# 5                                   can shrink concrete  Central heating
# 6                             shrink concrete buildings  Central heating
# 7     Buildings made of concrete but people did not ...  Central heating
# 8                       Concrete shrinks as it gets hot  Central heating
# 9              v concrete buildings become smaller heat  Central heating
# 10                       get small concrete as it dries  Central heating
# 11                                  can shrink concrete  Central heating
# 12               The central heating dries out concrete  Central heating
# 13                                     concrete shrinks  Central heating
# 14                           Concrete can dry out by CV  Central heating
# 15                                            dries out  Central heating
# 16                     concrete drying by using heating  Central heating
# 17                      using the CV concrete dries out  Central heating
# 18                central heating in concrete buildings  Central heating
# 19                      in many buildings thermal plant  Central heating
# 20         concrete shrinkage by use of central heating  Central heating
# 21     heating in concrete buildings can cause problems  Central heating
# 22         in a (concrete) buildings is increasingly CV  Central heating
# 23                        concrete shrinkage by heating  Central heating
# 24      Many buildings have a resume that radiates heat  Central heating
# 25    if buildings are not inspected at all of concr...  Central heating
# 26                      Concrete buildings with heating  Central heating
# 27    concrete buildings were built where central he...  Central heating
# 28                                           by heating  Central heating
# 29                 central heating in concrete building  Central heating
# ...                                                 ...              ...
# 1755                                       less expense   Suez canal dug
# 1756  channel connection between the Mediterranean a...   Suez canal dug
# 1757                              Now not around Africa   Suez canal dug
# 1758                           they made the Suez Canal   Suez canal dug
# 1759                                shorter trade route   Suez canal dug
# 1760                                     Suez canal dug   Suez canal dug
# 1761                     Hoefen ships not ignore Africa   Suez canal dug
# 1762                                   Sueskanaal built   Suez canal dug
# 1763                             the channel was opened   Suez canal dug
# 1764               of 10000+ nm to 6538 nm to Rotterdam   Suez canal dug
# 1765                                 the Suez Canal was   Suez canal dug
# 1766                            Suez canal construction   Suez canal dug
# 1767                     the distance is reduced by 40%   Suez canal dug
# 1768                             The Suez Canal was dug   Suez canal dug
# 1769                                     dug Suez Canal   Suez canal dug
# 1770                people do not a large piece of land   Suez canal dug
# 1771                       the trip is shortened by 40%   Suez canal dug
# 1772    Trade does not have the whole African continent   Suez canal dug
# 1773                                       channel open   Suez canal dug
# 1774               they built the Suez canal eventually   Suez canal dug
# 1775                  boats sail through the Suez canal   Suez canal dug
# 1776                                 Can you underneath   Suez canal dug
# 1777                 the Suez canal was dug by laborers   Suez canal dug
# 1778                          the Suez Canal was opened   Suez canal dug
# 1779     more transportation and much shorter distances   Suez canal dug
# 1780               a channel that shortens the distance   Suez canal dug
# 1781                    habituation to money and luxury   Suez canal dug
# 1782                           many distances shortened   Suez canal dug
# 1783                                      zeemiles less   Suez canal dug
# 1784               Suez Canal opened in 1842 scheepsweg   Suez canal dug
#
#      Accuracy_score Code     Fieldname
# 0                 4    g  Beton;Field1
# 1                 3    g  Beton;Field1
# 2                 3    g  Beton;Field1
# 3                 3    g  Beton;Field1
# 4                 3    g  Beton;Field1
# 5                 3    g  Beton;Field1
# 6                 3    g  Beton;Field1
# 7                 3    g  Beton;Field1
# 8                 3    g  Beton;Field1
# 9                 3    g  Beton;Field1
# 10                3    g  Beton;Field1
# 11                3    g  Beton;Field1
# 12                2    g  Beton;Field1
# 13                2    g  Beton;Field1
# 14                2    g  Beton;Field1
# 15                2    g  Beton;Field1
# 16                2    g  Beton;Field1
# 17                2    g  Beton;Field1
# 18                1    g  Beton;Field1
# 19                1    g  Beton;Field1
# 20                1    g  Beton;Field1
# 21                1    g  Beton;Field1
# 22                1    g  Beton;Field1
# 23                1    g  Beton;Field1
# 24                1    g  Beton;Field1
# 25                1    g  Beton;Field1
# 26                1    g  Beton;Field1
# 27                1    g  Beton;Field1
# 28                1    g  Beton;Field1
# 29                1    g  Beton;Field1
# ...             ...  ...           ...
# 1755              0    c   Suez;Field4
# 1756              0    c   Suez;Field4
# 1757              0    c   Suez;Field4
# 1758              4    g   Suez;Field4
# 1759              0    c   Suez;Field4
# 1760              4    g   Suez;Field4
# 1761              0    c   Suez;Field4
# 1762              4    g   Suez;Field4
# 1763              4    g   Suez;Field4
# 1764              0    c   Suez;Field4
# 1765              4    g   Suez;Field4
# 1766              4    g   Suez;Field4
# 1767              0    c   Suez;Field4
# 1768              4    g   Suez;Field4
# 1769              4    g   Suez;Field4
# 1770              0    c   Suez;Field4
# 1771              0    c   Suez;Field4
# 1772              0    c   Suez;Field4
# 1773              4    g   Suez;Field4
# 1774              4    g   Suez;Field4
# 1775              0    c   Suez;Field4
# 1776              0    c   Suez;Field4
# 1777              0    c   Suez;Field4
# 1778              4    g   Suez;Field4
# 1779              5    g   Suez;Field4
# 1780              4    g   Suez;Field4
# 1781              0    c   Suez;Field4
# 1782              0    c   Suez;Field4
# 1783              0    c   Suez;Field4
# 1784              4    g   Suez;Field4
#
# [1785 rows x 7 columns]

# %% [markdown]
# ## Bibliography
#
# <li>
#     <a href="https://www.hindawi.com/journals/mpe/2015/203475/">
#         Calculation of Sentence Semantic Similarity Based on Syntactic Structure
# Xiao Li1 and Qingsheng Li1,2
#     </a> - Super cool article about merging analysis of sentence structure  with the analysis of meaning in terms of Wordnet-like models
# </li>
# <li>
#     <a href="http://nlp.town/blog/sentence-similarity/">
#         Comparing Sentence Similarity Methods
#     </a> - Amazing comparison + summary with Jupyter notebook reference included
# </li>
#
# <li>
#     <a href="https://github.com/nlptown/nlp-notebooks">
#     cross lingual embedding repo
#     </a> - same guy as above
# </li>
# <li>
# https://nlp.stanford.edu/projects/glove/ - source of GloVe dataset
# </li>

# %% [markdown]
# ## To Read
# - https://arxiv.org/pdf/1802.05667.pdf
# - http://searchivarius.org/blog/brief-overview-querysentence-similarity-functions
# - https://www.irjet.net/archives/V4/i1/IRJET-V4I129.pdf
# - http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.210.9942&rep=rep1&type=pdf

# %% [markdown]
# ## More Bibliography:
#
#
# Thiede, K. W., Anderson, M. C. M., & Therriault, D. (2003). Accuracy of metacognitive monitoring affects learning of texts. Journal of Educational Psychology, 95, 66-73
# De Bruin, A.B.H., Dunlosky, J., & Cavalcanti. R.B. (2017). Monitoring and regulation of learning in medical education: The need for predictive cues. Medical Education, 51, 575-58
# Van Loon, M.H., De Bruin, A.B.H., Van Gog, T., & Van Merriënboer, J.J.G., & Dunlosky, J. (2014). Can students evaluate their understanding of cause-and-effect relations? The effects of diagram completion on monitoring accuracy. Acta Psychologica, 151, 143-154.
#
# De Bruin, A.B.H, Kok, E.M., Lobbestael, J., & de Grip, A. (2017). The impact of an online tool for monitoring and regulating learning at university: overconfidence, learning strategy, and personality. Metacognition and Learning, 12, 21-43.
#
# De Bruin, A.B.H, & van Merriënboer, J.J. (2017). Bridging Cognitive Load and Self-Regulated Learning Research: A complementary approach to contemporary issues in educational research. Learning and Instruction, 51, 1-9.
